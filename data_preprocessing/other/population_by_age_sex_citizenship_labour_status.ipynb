# %%
import pandas as pd

# %% [markdown]
# **Population on 1 January by age group, sex and citizenship**
#
# * Unit: Number
# * Age classes:
#     * 'Less than 15 years', 'From 15 to 19 years', 'From 20 to 24 years',
#        'From 25 to 29 years', 'From 30 to 34 years',
#        'From 35 to 39 years', 'From 40 to 44 years',
#        'From 45 to 49 years', 'From 50 to 54 years',
#        'From 55 to 59 years', 'From 60 to 64 years', '65 years or over', 'Total'
# * Sex:
#     * 'Males', 'Females', 'Total'
# * Citizenship:
#     * 'Foreign country and stateless'	, 'Total'

# %%
df = pd.read_csv('../../data/population_foreigners.csv')

# %%
df.head()
# Out:
#   STRUCTURE             STRUCTURE_ID  \
# 0  dataflow  ESTAT:MIGR_POP1CTZ(1.0)
# 1  dataflow  ESTAT:MIGR_POP1CTZ(1.0)
# 2  dataflow  ESTAT:MIGR_POP1CTZ(1.0)
# 3  dataflow  ESTAT:MIGR_POP1CTZ(1.0)
# 4  dataflow  ESTAT:MIGR_POP1CTZ(1.0)
#
#                                       STRUCTURE_NAME freq Time frequency  \
# 0  Population on 1 January by age group, sex and ...    A         Annual
# 1  Population on 1 January by age group, sex and ...    A         Annual
# 2  Population on 1 January by age group, sex and ...    A         Annual
# 3  Population on 1 January by age group, sex and ...    A         Annual
# 4  Population on 1 January by age group, sex and ...    A         Annual
#
#     citizen         Country of citizenship    age Age class unit  ... geo  \
# 0  FOR_STLS  Foreign country and stateless  TOTAL     Total   NR  ...  AT
# 1  FOR_STLS  Foreign country and stateless  TOTAL     Total   NR  ...  AT
# ...

# %%
df.columns
# Out:
# Index(['STRUCTURE', 'STRUCTURE_ID', 'STRUCTURE_NAME', 'freq', 'Time frequency',
#        'citizen', 'Country of citizenship', 'age', 'Age class', 'unit',
#        'Unit of measure', 'sex', 'Sex', 'geo',
#        'Geopolitical entity (reporting)', 'TIME_PERIOD', 'Time', 'OBS_VALUE',
#        'Observation value', 'OBS_FLAG',
#        'Observation status (Flag) V2 structure', 'CONF_STATUS',
#        'Confidentiality status (flag)'],
#       dtype='object')

# %%
df = df[['Sex', 'Geopolitical entity (reporting)', 'Age class', 'TIME_PERIOD', 'Country of citizenship', 'OBS_VALUE']]

# %%
df.head()
# Out:
#        Sex Geopolitical entity (reporting) Age class  TIME_PERIOD  \
# 0  Females                         Austria     Total         2012
# 1  Females                         Austria     Total         2013
# 2  Females                         Austria     Total         2014
# 3  Females                         Austria     Total         2015
# 4  Females                         Austria     Total         2016
#
#           Country of citizenship  OBS_VALUE
# 0  Foreign country and stateless     470822
# 1  Foreign country and stateless     496844
# 2  Foreign country and stateless     526542
# 3  Foreign country and stateless     562672
# 4  Foreign country and stateless     611580

# %%
df['Age class'].unique()
# Out:
# array(['Total', 'From 15 to 19 years', 'From 20 to 24 years',
#        'From 25 to 29 years', 'From 30 to 34 years',
#        'From 35 to 39 years', 'From 40 to 44 years',
#        'From 45 to 49 years', 'From 50 to 54 years',
#        'From 55 to 59 years', 'From 60 to 64 years', '65 years or over',
#        'Less than 15 years'], dtype=object)

# %%
df = df.rename(columns={
    'Geopolitical entity (reporting)': 'geo',
    'OBS_VALUE': 'Number'
})

# %%
df.head()
# Out:
#        Sex      geo Age class  TIME_PERIOD         Country of citizenship  \
# 0  Females  Austria     Total         2012  Foreign country and stateless
# 1  Females  Austria     Total         2013  Foreign country and stateless
# 2  Females  Austria     Total         2014  Foreign country and stateless
# 3  Females  Austria     Total         2015  Foreign country and stateless
# 4  Females  Austria     Total         2016  Foreign country and stateless
#
#    Number
# 0  470822
# 1  496844
# 2  526542
# 3  562672
# 4  611580

# %%
df.to_csv("../../processed_data/population_foreigners.csv", index=False)
