# %%
import pandas as pd

# %% [markdown]
# # Population on 1 January by broad age group
# * age group: 15-64
# * do wyliczeń związanych z osobami w wieku produkcyjnym

# %%
df = pd.read_csv('../../data/population_15_64_age_group.csv')

# %%
df.head()
# Out:
#   STRUCTURE               STRUCTURE_ID  \
# 0  dataflow  ESTAT:DEMO_PJANBROAD(1.0)
# 1  dataflow  ESTAT:DEMO_PJANBROAD(1.0)
# 2  dataflow  ESTAT:DEMO_PJANBROAD(1.0)
# 3  dataflow  ESTAT:DEMO_PJANBROAD(1.0)
# 4  dataflow  ESTAT:DEMO_PJANBROAD(1.0)
#
#                                       STRUCTURE_NAME freq Time frequency unit  \
# 0  Population on 1 January by broad age group and...    A         Annual   NR
# 1  Population on 1 January by broad age group and...    A         Annual   NR
# 2  Population on 1 January by broad age group and...    A         Annual   NR
# 3  Population on 1 January by broad age group and...    A         Annual   NR
# 4  Population on 1 January by broad age group and...    A         Annual   NR
#
#   Unit of measure     age            Age class sex  ... geo  \
# 0          Number  Y15-64  From 15 to 64 years   T  ...  AD
# 1          Number  Y15-64  From 15 to 64 years   T  ...  AD
# 2          Number  Y15-64  From 15 to 64 years   T  ...  AD
# ...

# %%
df = df[['Geopolitical entity (reporting)','TIME_PERIOD', 'OBS_VALUE']]

# %%
df.head()
# Out:
#   Geopolitical entity (reporting)  TIME_PERIOD  OBS_VALUE
# 0                         Andorra         1986    32107.0
# 1                         Andorra         1987    33856.0
# 2                         Andorra         1988    34940.0
# 3                         Andorra         1989    36624.0
# 4                         Andorra         1990    36708.0

# %%
df = df.rename(columns={
    'Geopolitical entity (reporting)': 'geo', 
    'TIME_PERIOD': 'year',
    'OBS_VALUE': 'population_15_64'
})

# %%
df.head()
# Out:
#        geo  year  population_15_64
# 0  Andorra  1986           32107.0
# 1  Andorra  1987           33856.0
# 2  Andorra  1988           34940.0
# 3  Andorra  1989           36624.0
# 4  Andorra  1990           36708.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2199 entries, 0 to 2198
# Data columns (total 3 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   geo               2199 non-null   object
#  1   year              2199 non-null   int64
#  2   population_15_64  2199 non-null   float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 51.7+ KB

# %%
df.to_csv("../../processed_data/population_15_64.csv", index=False)
