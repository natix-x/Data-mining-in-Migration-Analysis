# %%
import pandas as pd

# %% [markdown]
# **Unemployment rates by citizenship and sex**
#
# ---
#
# Unemployment rate (Eurostat) is calculated according to the International Labour Organization (ILO) definition as:
#
# Unemployment rate = (Number of unemployed people / Labour force )× 100 %
#
# Unemployed people: Those who are not working, actively seeking work in the last 4 weeks, and available to start within 2 weeks.
#
# Labour force: Sum of employed and unemployed people.

# %%
df = pd.read_csv('../../data/unemployment_rates_by_sex_and_citizenship.csv')

# %%
df.head()
# Out:
#   STRUCTURE           STRUCTURE_ID  \
# 0  dataflow  ESTAT:LFSQ_URGAN(1.0)
# 1  dataflow  ESTAT:LFSQ_URGAN(1.0)
# 2  dataflow  ESTAT:LFSQ_URGAN(1.0)
# 3  dataflow  ESTAT:LFSQ_URGAN(1.0)
# 4  dataflow  ESTAT:LFSQ_URGAN(1.0)
#
#                                       STRUCTURE_NAME freq Time frequency unit  \
# 0  Unemployment rates by sex, age and citizenship...    Q      Quarterly   PC
# 1  Unemployment rates by sex, age and citizenship...    Q      Quarterly   PC
# 2  Unemployment rates by sex, age and citizenship...    Q      Quarterly   PC
# 3  Unemployment rates by sex, age and citizenship...    Q      Quarterly   PC
# 4  Unemployment rates by sex, age and citizenship...    Q      Quarterly   PC
#
#   Unit of measure sex      Sex     age  ... geo  \
# 0      Percentage   F  Females  Y15-64  ...  AT
# 1      Percentage   F  Females  Y15-64  ...  AT
# 2      Percentage   F  Females  Y15-64  ...  AT
# 3      Percentage   F  Females  Y15-64  ...  AT
# 4      Percentage   F  Females  Y15-64  ...  AT
#
#   Geopolitical entity (reporting) TIME_PERIOD Time OBS_VALUE  \
# 0                         Austria     1998-Q1  NaN       8.9
# 1                         Austria     1999-Q1  NaN       9.2
# 2                         Austria     2000-Q1  NaN       9.0
# 3                         Austria     2000-Q2  NaN       5.7
# 4                         Austria     2001-Q1  NaN       7.9
#
#   Observation value  OBS_FLAG  Observation status (Flag) V2 structure  \
# 0               NaN       NaN                                     NaN
# 1               NaN       NaN                                     NaN
# 2               NaN       NaN                                     NaN
# 3               NaN         u                         low reliability
# 4               NaN       NaN                                     NaN
#
#    CONF_STATUS Confidentiality status (flag)
# 0          NaN                           NaN
# 1          NaN                           NaN
# 2          NaN                           NaN
# 3          NaN                           NaN
# 4          NaN                           NaN
#
# [5 rows x 23 columns]

# %%
df = df[["Country of citizenship", "Geopolitical entity (reporting)", "OBS_VALUE", "TIME_PERIOD", "Sex"]]

# %%
df.head()
# Out:
#   Country of citizenship Geopolitical entity (reporting)  OBS_VALUE  \
# 0        Foreign country                         Austria        8.9
# 1        Foreign country                         Austria        9.2
# 2        Foreign country                         Austria        9.0
# 3        Foreign country                         Austria        5.7
# 4        Foreign country                         Austria        7.9
#
#   TIME_PERIOD      Sex
# 0     1998-Q1  Females
# 1     1999-Q1  Females
# 2     2000-Q1  Females
# 3     2000-Q2  Females
# 4     2001-Q1  Females

# %%
df.dropna(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 25355 entries, 0 to 28472
# Data columns (total 5 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Country of citizenship           25355 non-null  object
#  1   Geopolitical entity (reporting)  25355 non-null  object
#  2   OBS_VALUE                        25355 non-null  float64
#  3   TIME_PERIOD                      25355 non-null  object
#  4   Sex                              25355 non-null  object
# dtypes: float64(1), object(4)
# memory usage: 1.2+ MB

# %%
df = df.rename(columns={
    "Geopolitical entity (reporting)": "geo",
    "TIME_PERIOD": "quarter",
    "OBS_VALUE": "unemployment_rate", 
    "Country of citizenship": "citizenship"
})

# %%
df.to_csv("../../processed_data/unemploymnet_rates.csv", index=False)
