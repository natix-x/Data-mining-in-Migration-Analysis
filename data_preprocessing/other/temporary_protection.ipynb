# %%
import pandas as pd

# %%
df = pd.read_csv('../../data/temporary_protection_beneficiaries_monthly.csv')

# %%
df.head()
# Out:
#   STRUCTURE             STRUCTURE_ID  \
# 0  dataflow  ESTAT:MIGR_ASYTPSM(1.0)
# 1  dataflow  ESTAT:MIGR_ASYTPSM(1.0)
# 2  dataflow  ESTAT:MIGR_ASYTPSM(1.0)
# 3  dataflow  ESTAT:MIGR_ASYTPSM(1.0)
# 4  dataflow  ESTAT:MIGR_ASYTPSM(1.0)
#
#                                       STRUCTURE_NAME freq Time frequency unit  \
# 0  Beneficiaries of temporary protection at the e...    M        Monthly  PER
# 1  Beneficiaries of temporary protection at the e...    M        Monthly  PER
# 2  Beneficiaries of temporary protection at the e...    M        Monthly  PER
# 3  Beneficiaries of temporary protection at the e...    M        Monthly  PER
# 4  Beneficiaries of temporary protection at the e...    M        Monthly  PER
#
#   Unit of measure citizen Country of citizenship sex  ... geo  \
# 0          Person      UA                Ukraine   T  ...  AT
# 1          Person      UA                Ukraine   T  ...  AT
# 2          Person      UA                Ukraine   T  ...  AT
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1136 entries, 0 to 1135
# Data columns (total 23 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   STRUCTURE                               1136 non-null   object
#  1   STRUCTURE_ID                            1136 non-null   object
#  2   STRUCTURE_NAME                          1136 non-null   object
#  3   freq                                    1136 non-null   object
#  4   Time frequency                          1136 non-null   object
#  5   unit                                    1136 non-null   object
#  6   Unit of measure                         1136 non-null   object
#  7   citizen                                 1136 non-null   object
#  8   Country of citizenship                  1136 non-null   object
#  9   sex                                     1136 non-null   object
# ...

# %%
df = df[["Country of citizenship", "Geopolitical entity (reporting)", "OBS_VALUE", "TIME_PERIOD"]]
df = df.rename(columns={
    "Geopolitical entity (reporting)": "geo",
    "TIME_PERIOD": "month"
})

# %%
df.head()
# Out:
#   Country of citizenship      geo  OBS_VALUE    month
# 0                Ukraine  Austria    73785.0  2022-07
# 1                Ukraine  Austria    76920.0  2022-08
# 2                Ukraine  Austria    79735.0  2022-09
# 3                Ukraine  Austria    82310.0  2022-10
# 4                Ukraine  Austria    84380.0  2022-11

# %%
df.dropna(inplace=True)

# %%
df.to_csv("../../processed_data/ukraine_temporary_protection.csv", index=False)
