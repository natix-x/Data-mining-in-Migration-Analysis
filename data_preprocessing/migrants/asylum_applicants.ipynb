# %%
import pandas as pd

# %% [markdown]
# Asylum applicants by type, citizenship, age and sex - annual aggregated data

# %%
df = pd.read_csv('../../data/asylum_applicants_total.csv')

# %%
df.head()
# Out:
#   STRUCTURE                STRUCTURE_ID  \
# 0  dataflow  ESTAT:MIGR_ASYAPPCTZA(1.0)
# 1  dataflow  ESTAT:MIGR_ASYAPPCTZA(1.0)
# 2  dataflow  ESTAT:MIGR_ASYAPPCTZA(1.0)
# 3  dataflow  ESTAT:MIGR_ASYAPPCTZA(1.0)
# 4  dataflow  ESTAT:MIGR_ASYAPPCTZA(1.0)
#
#                                       STRUCTURE_NAME freq Time frequency  \
# 0  Asylum applicants by type, citizenship, age an...    A         Annual
# 1  Asylum applicants by type, citizenship, age an...    A         Annual
# 2  Asylum applicants by type, citizenship, age an...    A         Annual
# 3  Asylum applicants by type, citizenship, age an...    A         Annual
# 4  Asylum applicants by type, citizenship, age an...    A         Annual
#
#   citizen Country of citizenship sex    Sex unit  ... geo  \
# 0   TOTAL                  Total   T  Total  PER  ...  AT
# 1   TOTAL                  Total   T  Total  PER  ...  AT
# 2   TOTAL                  Total   T  Total  PER  ...  AT
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1080 entries, 0 to 1079
# Data columns (total 25 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   STRUCTURE                               1080 non-null   object
#  1   STRUCTURE_ID                            1080 non-null   object
#  2   STRUCTURE_NAME                          1080 non-null   object
#  3   freq                                    1080 non-null   object
#  4   Time frequency                          1080 non-null   object
#  5   citizen                                 1080 non-null   object
#  6   Country of citizenship                  1080 non-null   object
#  7   sex                                     1080 non-null   object
#  8   Sex                                     1080 non-null   object
#  9   unit                                    1080 non-null   object
# ...

# %%
df = df[['Country of citizenship', 'TIME_PERIOD', 'Geopolitical entity (reporting)', 'OBS_VALUE']]

# %%
df.head()
# Out:
#   Country of citizenship  TIME_PERIOD Geopolitical entity (reporting)  \
# 0                  Total         2008                         Austria
# 1                  Total         2009                         Austria
# 2                  Total         2010                         Austria
# 3                  Total         2011                         Austria
# 4                  Total         2012                         Austria
#
#    OBS_VALUE
# 0      12750
# 1      15815
# 2      11060
# 3      14455
# 4      17450

# %%
df = df.rename(columns={
    "OBS_VALUE": "Number",
    "Geopolitical entity (reporting)": "geo",
    "TIME_PERIOD": "year"
    })

# %%
df.head()
# Out:
#   Country of citizenship  year      geo  Number
# 0                  Total  2008  Austria   12750
# 1                  Total  2009  Austria   15815
# 2                  Total  2010  Austria   11060
# 3                  Total  2011  Austria   14455
# 4                  Total  2012  Austria   17450

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1080 entries, 0 to 1079
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Country of citizenship  1080 non-null   object
#  1   year                    1080 non-null   int64
#  2   geo                     1080 non-null   object
#  3   Number                  1080 non-null   int64
# dtypes: int64(2), object(2)
# memory usage: 33.9+ KB

# %%
df.to_csv("../../processed_data/asylum_applicants.csv", index=False)
