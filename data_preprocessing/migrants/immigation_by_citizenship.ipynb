# %%
import pandas as pd

df = pd.read_csv('../../data/immigration_by_citizenship.csv')

# %%
df.head()
# Out:
#   STRUCTURE             STRUCTURE_ID  \
# 0  dataflow  ESTAT:MIGR_IMM1CTZ(1.0)
# 1  dataflow  ESTAT:MIGR_IMM1CTZ(1.0)
# 2  dataflow  ESTAT:MIGR_IMM1CTZ(1.0)
# 3  dataflow  ESTAT:MIGR_IMM1CTZ(1.0)
# 4  dataflow  ESTAT:MIGR_IMM1CTZ(1.0)
#
#                                   STRUCTURE_NAME freq Time frequency citizen  \
# 0  Immigration by age group, sex and citizenship    A         Annual      AD
# 1  Immigration by age group, sex and citizenship    A         Annual      AD
# 2  Immigration by age group, sex and citizenship    A         Annual      AD
# 3  Immigration by age group, sex and citizenship    A         Annual      AD
# 4  Immigration by age group, sex and citizenship    A         Annual      AD
#
#   Country of citizenship agedef               Age definition    age  ... geo  \
# 0                Andorra  REACH  Age reached during the year  TOTAL  ...  AT
# 1                Andorra  REACH  Age reached during the year  TOTAL  ...  AT
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 133834 entries, 0 to 133833
# Data columns (total 25 columns):
#  #   Column                                  Non-Null Count   Dtype
# ---  ------                                  --------------   -----
#  0   STRUCTURE                               133834 non-null  object
#  1   STRUCTURE_ID                            133834 non-null  object
#  2   STRUCTURE_NAME                          133834 non-null  object
#  3   freq                                    133834 non-null  object
#  4   Time frequency                          133834 non-null  object
#  5   citizen                                 133317 non-null  object
#  6   Country of citizenship                  133834 non-null  object
#  7   agedef                                  133834 non-null  object
#  8   Age definition                          133834 non-null  object
#  9   age                                     133834 non-null  object
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()
# Out:
# STRUCTURE                                      0
# STRUCTURE_ID                                   0
# STRUCTURE_NAME                                 0
# freq                                           0
# Time frequency                                 0
# citizen                                      517
# Country of citizenship                         0
# agedef                                         0
# Age definition                                 0
# age                                            0
# Age class                                      0
# unit                                           0
# Unit of measure                                0
# sex                                            0
# Sex                                            0
# geo                                            0
# Geopolitical entity (reporting)                0
# TIME_PERIOD                                    0
# Time                                      133834
# ...

# %%
df = df.drop(columns=["STRUCTURE", "STRUCTURE_ID", "STRUCTURE_NAME", "Time", "Observation value", "OBS_FLAG", "Observation status (Flag) V2 structure", "CONF_STATUS", "Confidentiality status (flag)"])

# %%
df.dropna(inplace=True)

# %%
for col in df.columns:
    print(f"Uniques values in {col}: {df[col].unique()}")
# Out:
# Uniques values in freq: ['A']
# Uniques values in Time frequency: ['Annual']
# Uniques values in citizen: ['AD' 'AE' 'AF' 'AFR' 'AFR_C' 'AFR_E' 'AFR_N' 'AFR_OTH' 'AFR_S' 'AFR_W'
#  'AG' 'AI' 'AL' 'AM' 'AME' 'AME_C' 'AME_N' 'AME_OTH' 'AME_S' 'AN' 'AO'
#  'AR' 'ASI' 'ASI_C' 'ASI_E' 'ASI_OTH' 'ASI_S' 'ASI_S_E' 'ASI_W' 'AT' 'AU'
#  'AU_NZ' 'AW' 'AZ' 'BA' 'BB' 'BD' 'BE' 'BF' 'BG' 'BH' 'BI' 'BJ' 'BL' 'BM'
#  'BN' 'BO' 'BQ' 'BR' 'BS' 'BT' 'BW' 'BY' 'BZ' 'CA' 'CC3_07' 'CC4_10'
#  'CC8_22_FOR' 'CC9_23_FOR' 'CD' 'CF' 'CG' 'CH' 'CI' 'CL' 'CM' 'CN' 'CO'
#  'CR' 'CRB' 'CU' 'CV' 'CW' 'CY' 'CZ' 'CZ_SK' 'DE' 'DJ' 'DK' 'DM' 'DO' 'DZ'
#  'EC' 'EE' 'EFTA' 'EFTA_FOR' 'EG' 'EH' 'EL' 'ER' 'ES' 'ET' 'EU15'
#  'EU15_FOR' 'EU25' 'EU25_FOR' 'EU27_2007' 'EU27_2007_FOR' 'EU27_2020_FOR'
#  'EU28_FOR' 'EUR' 'EUR_OTH' 'EXT' 'EX_SU' 'EX_YU' 'FI' 'FJ' 'FK' 'FM' 'FO'
#  'FOR_STLS' 'FR' 'GA' 'GD' 'GE' 'GG' 'GH' 'GI' 'GL' 'GM' 'GN' 'GQ' 'GT'
#  'GW' 'GY' 'HDC_EXT' 'HN' 'HR' 'HT' 'HU' 'ID' 'IE' 'IL' 'IM' 'IN' 'IQ'
# ...

# %%
df = df.drop(columns=["sex", "Sex", "age", "Age definition", "Age class", "unit", "agedef", "freq", "Time frequency"])

# %%
df.head()
# Out:
#   citizen Country of citizenship Unit of measure geo  \
# 0      AD                Andorra          Number  AT
# 1      AD                Andorra          Number  AT
# 2      AD                Andorra          Number  AT
# 3      AD                Andorra          Number  AT
# 4      AD                Andorra          Number  AT
#
#   Geopolitical entity (reporting)  TIME_PERIOD  OBS_VALUE
# 0                         Austria         1998        1.0
# 1                         Austria         1999        1.0
# 2                         Austria         2001        0.0
# 3                         Austria         2002        0.0
# 4                         Austria         2003        0.0

# %%
df = df.drop(columns=["geo", "citizen"])

# %%
df.rename(columns={"Geopolitical entity (reporting)":"geo", "OBS_VALUE":"Migrants number", "TIME_PERIOD": "year"}, inplace=True)

# %%
df = df.drop(columns=["Unit of measure"])

# %%
df.head()
# Out:
#   Country of citizenship      geo  year  Migrants number
# 0                Andorra  Austria  1998              1.0
# 1                Andorra  Austria  1999              1.0
# 2                Andorra  Austria  2001              0.0
# 3                Andorra  Austria  2002              0.0
# 4                Andorra  Austria  2003              0.0

# %%
df.to_csv("../../processed_data/immigration_by_citizenship.csv", index=False)
